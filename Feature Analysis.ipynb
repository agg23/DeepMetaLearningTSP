# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_pickle("../data/features/analysis.pickle")

# %%
import re
columnNames = list(df)
regexTimes = re.compile(".*Times")
timesColumnNames = list(filter(regexTimes.match, columnNames))

sumDF = pd.DataFrame(columns=["Sum", "Values"])
for column in timesColumnNames:
    newDF = pd.DataFrame([[column, df[column].sum()]], columns=["Sum", "Values"])
    sumDF = sumDF.append(newDF)

# %%
sumDF = sumDF.set_index("Sum")

# %%
sumDF.sort_values(["Values"], ascending=False)
# Out:
#                                                          Values
# Sum
# complexFeatures.alternateClusteringCoefficientT...  2623.848076
# heuristics.graspTimes                               2460.028333
# complexFeatures.weightedClusteringCoefficientTimes  2366.627382
# heuristics.antColonyTimes                           2312.285660
# complexFeatures.networkCyclicCoefficientTimes       2233.172605
# complexFeatures.clusteringCoefficientTransitivi...  2056.338698
# heuristics.tabuTimes                                1781.549562
# complexFeatures.averageShortestPathGeodesicDist...  1535.107620
# heuristics.simulatedAnnealingTimes                  1470.589060
# heuristicFeatures.greedySolutionsPrepTimes          1182.338461
# heuristics.geneticTimes                              600.283049
# heuristicFeatures.randomNeighborSolutionQuality...   137.939133
# heuristicFeatures.greedySolutionQualityTimes         136.173222
# heuristicFeatures.averageRatioNeighborsWithBett...   136.166178
# heuristicFeatures.averageRatioGreedySolutionTimes    135.560205
# heuristicFeatures.proportionsNeighborsWithBette...   134.269943
# complexFeatures.adjacencyCorrelationCoefficient...    59.961958
# heuristicFeatures.averageTimesOffspringBetterSo...    39.956500
# complexFeatures.edgeDegreeCorrelationTimes            22.911873
# complexFeatures.connectedEdgeCountsPrepTimes          17.261024
# complexFeatures.targetEntropyTimes                    11.510660
# complexFeatures.edgeReciprocityTimes                   8.272526
# heuristicFeatures.averageTimesOffspringBetterSo...     8.125176
# heuristicFeatures.randomNeighborSolutionsPrepTimes     7.034921
# simpleFeatures.vertexCostPrepTimes                     6.068515
# heuristicFeatures.proportionOffspringBetterSolu...     5.461850
# heuristicFeatures.averageRatioOffspringBetterSo...     5.431216
# heuristicFeatures.childrenSolutionPairsPrepTimes       4.192032
# simpleFeatures.sumCostNearestNeighborTimes             2.871482
# heuristicFeatures.averageSharedEdgesTimes              2.547692
# heuristicFeatures.greedyEdgesPrepTimes                 1.061237
# heuristicFeatures.relativeFrequencyCommonGreedy...     0.876992
# complexFeatures.networkVulnerabilityTimes              0.539816
# simpleFeatures.sumNLowestEdgeCostTimes                 0.344249
# heuristicFeatures.randomSolutionsPrepTimes             0.227991
# complexFeatures.averageGeodesicDistanceTimes           0.113232
# complexFeatures.globalEfficiencyTimes                  0.112867
# simpleFeatures.lowestEdgeCostTimes                     0.111783
# complexFeatures.harmonicMeanGeodesicDistanceTimes      0.107469
# simpleFeatures.averageEdgeCostTimes                    0.095330
# heuristicFeatures.parentSolutionPairsPrepTimes         0.054447
# simpleFeatures.medianEdgeCostTimes                     0.051174
# simpleFeatures.standardDeviationEdgeCostTimes          0.016974
# simpleFeatures.medianVertexCostTimes                   0.009697
# simpleFeatures.standardDeviationVertexCostTimes        0.007517
# simpleFeatures.numberEdgesTimes                        0.005415
# simpleFeatures.averageVertexCostTimes                  0.003391
# simpleFeatures.lowestVertexCostTimes                   0.002973
# simpleFeatures.highestEdgeCostTimes                    0.002721
# complexFeatures.maxVertexDegreeTimes                   0.001993
# simpleFeatures.highestVertexCostTimes                  0.001292
# complexFeatures.entropyDegreeDistributionTimes         0.000562
# simpleFeatures.numberVerticesTimes                     0.000536
# complexFeatures.vertexParticipationCoefficientT...     0.000238

# %%
sumDF.sum()/60/60
# Out:
# Values    5.974343
# dtype: float64
