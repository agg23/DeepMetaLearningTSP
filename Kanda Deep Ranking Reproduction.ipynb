# %%
import numpy as np
import pandas as pd

import tensorflow as tf

from sklearn.preprocessing import scale
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score

import time
import math

# %%
df = pd.read_pickle("../data/large200analysis.pickle")

# %%
df = df.loc[df["metadata.isAsymmetric"] == False]

# %%
# Drop NA columns
df = df.drop("complexFeatures.entropyDegreeDistribution", axis=1)
df = df.drop("complexFeatures.vertexParticipationCoefficient", axis=1)

# %%
import re
columnNames = list(df)
regexTimes = re.compile(".*Times")
timesColumnNames = list(filter(regexTimes.match, columnNames))
for column in timesColumnNames:
    columnNames.remove(column)
    
regexCosts = re.compile("heuristics.*Costs")
costsColumnNames = list(filter(regexCosts.match, columnNames))
for column in costsColumnNames:
    columnNames.remove(column)

columnNames.remove("metadata.isAsymmetric")
columnNames.remove("generated")
columnNames.remove("deepWalk")
columnNames.remove("sequenceLength")
columnNames.remove("costs")

# %%
# Drop rows with NA
rowsBefore = df.shape[0]
df = df.dropna()
print("Dropped %d rows due to None values" % (rowsBefore - df.shape[0]))

costValues = df[["heuristics.tabuCosts", "heuristics.simulatedAnnealingCosts", "heuristics.graspCosts", "heuristics.geneticCosts", "heuristics.antColonyCosts"]].values
indexRankings = costValues.argsort()

# Remove all *Times columns
df = df[columnNames]

# Remove name column
df = df.drop(["name"], axis=1)
# Out:
# Dropped 0 rows due to None values

# %%
size = df.shape[0]
# Test data is separated in cleaning stage
trainSize = int(size * 0.75)
validSize = size - trainSize

inputs = scale(df.astype('float64'),axis=1)

inputsTrain = inputs[0:trainSize]
outputsTrain = indexRankings[0:trainSize]

inputsValid = inputs[trainSize:]
outputsValid = indexRankings[trainSize:]
# Out:
# /home/gastinad/.local/lib/python3.6/site-packages/sklearn/preprocessing/data.py:164: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
inputsValid.shape
# Out:
# (2155, 37)

# %%
outputsTrain
# Out:
# array([[2, 0, 4, 1, 3],
#        [2, 0, 4, 1, 3],
#        [2, 0, 4, 1, 3],
#        ...,
#        [2, 4, 3, 1, 0],
#        [2, 4, 3, 1, 0],
#        [2, 4, 3, 1, 0]])

# %%
EPOCHS = 1000

N1 = trainSize
FEATURE_COUNT = df.shape[1]
LABEL_COUNT = 5

NODES1 = 512
NODES2 = 512
NODES3 = 256
NODES4 = 256
NODES5 = 128
NODES6 = 128
NODES7 = 64

ALPHA = 0.001

BATCH_SIZE = 2

STD = 0.1

LEARNING_RATE = 0.00001

# %%
# Define the input function for training
inputFunc = tf.estimator.inputs.numpy_input_fn(
    x={"input": inputsTrain.astype(np.float32)}, y=outputsTrain.astype(np.float32),
#     batch_size=BATCH_SIZE, num_epochs=EPOCHS, shuffle=True)
    num_epochs=EPOCHS, shuffle=True)

# %%
# Define the neural network
def network(xDict, mode):
    x = xDict["input"]
        
    regularizer = tf.contrib.layers.l2_regularizer(scale=ALPHA)
    
    layer1 = tf.layers.dense(x, NODES1, kernel_regularizer=regularizer, activation=tf.nn.relu)
    
    layer2 = tf.layers.dense(layer1, NODES2, activation=tf.nn.relu)
    layer3 = tf.layers.dense(layer2, NODES3, activation=tf.nn.relu)
    layer4 = tf.layers.dense(layer3, NODES4, activation=tf.nn.relu)
    layer5 = tf.layers.dense(layer4, NODES5, activation=tf.nn.relu)
    layer6 = tf.layers.dense(layer5, NODES6, activation=tf.nn.relu)
    layer7 = tf.layers.dense(layer6, NODES7, activation=tf.nn.relu)
    # Output fully connected layer with a neuron for each class
    outLayer = tf.layers.dense(layer7, LABEL_COUNT)
    return outLayer

# %% [markdown]
# # Loss Functions

# %%
def listNetLoss(label, prediction):
    softMaxLabel = tf.nn.softmax(label)
    softMaxPrediction = tf.nn.softmax(prediction)
    return -tf.reduce_mean(softMaxLabel * tf.log(softMaxPrediction))

def log2(x):
    numerator = tf.log(x)
    denominator = tf.log(tf.constant(2, dtype=numerator.dtype))
    return numerator / denominator


# Builds an integer ranking out of a 1-D tensor
def convertPredToRank(prediction):
    return tf.cast(tf.nn.top_k(prediction, k=5).indices, dtype=tf.float32)

# %% [markdown]
# # Accuracy Measures

# %%
# Accuracy metric using Normalized Discounted Cumulative Gain, as per https://github.com/shiba24/learning2rank/
def ndcg(labels, predictions, k=5):
    topK = tf.nn.top_k(labels, k=5)
    sortedValues = topK.values
    sortedIndices = topK.indices
#         print(labelSorted)
#         labelSorted = sorted(label, reverse=True)
    ideal_dcg = 0
    for i in range(k):
#             ideal_dcg += (2 ** labelSorted[:i] - 1.) / log2(tf.cast(i + 2, tf.float64))
        ideal_dcg += (tf.cast(sortedValues[i] + 1, tf.float32)) / log2(tf.cast(i + 2, tf.float32))
    dcg = 0
#         argsort_indices = np.argsort(predictions)[::-1]
#         argsort_indices = tf.nn.top_k(predictions, k=5).indices
#         print(argsort_indices)
    for i in range(k):
        dcg += (tf.gather(predictions, sortedIndices[i]) + 1) / log2(tf.cast(i + 2, tf.float32))
#         dcg += (predictions[i] + 1) / log2(tf.cast(i + 2, tf.float64))
    return dcg / ideal_dcg

def spearmanCorrelation(label, prediction):
    length = tf.cast(tf.shape(prediction)[0], tf.float32)
    sumVal = tf.reduce_sum(tf.square(tf.subtract(prediction, label)))
    return 1 - 6 * sumVal / (length ** 3 - length)

# Bound Spearman coeff. between 0 and 1
def boundedSpearman(label, prediction):
    return (spearmanCorrelation(label, prediction) + 1.)/2

def top1Match(label, prediction):
    return tf.cast(tf.equal(label[0], prediction[0]), tf.float32)

def top2Match(label, prediction):
    sameFirstOrSecond = tf.logical_or(tf.equal(label[0], prediction[0]), tf.equal(label[1], prediction[1]))
    sameFirstAndSecond = tf.logical_or(tf.equal(label[1], prediction[0]), tf.equal(label[0], prediction[1]))
    return tf.cast(tf.logical_or(sameFirstOrSecond, sameFirstAndSecond), tf.float32)

# %%
# Define the model function (following TF Estimator Template)
def modelFunc(features, labels, mode):
    # Build the neural network
    logits = network(features, mode)
    
#     resizedLogits = tf.reshape(logits, shape=[-1, MAX_SIZE * MAX_SIZE, 1])
    
    # Predictions
    # TODO: Possibly need to change
#     pred_classes = logits
    pred_classes = tf.map_fn(convertPredToRank, logits)
#     pred_classes = tf.argmax(logits, axis=1)
#     pred_probas = tf.nn.softmax(logits)
    
    # If prediction mode, early return
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=pred_classes)
    
    # Define loss and optimizer
#     loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
#         logits=logits, labels=tf.cast(labels, dtype=tf.int32)))
#     loss_op = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(
#         logits=logits, labels=labels))
#     loss_op = tf.reduce_mean(loss(labels, logits))
    loss_op = tf.reduce_mean(listNetLoss(labels, logits))
#     loss_map = tf.map_fn(lambda x: listMLE2(x[0], x[1]), (labels, pred_classes), dtype=tf.float64)
#     print(labels.get_shape()[0])
#     labels_length = tf.shape(labels)[0]
#     loss_op = tf.reduce_mean(listMLE2Loss(labels, logits, labels_length, tf.cast(labels_length, dtype=tf.float32)))
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate=LEARNING_RATE)
    optimizer = tf.contrib.opt.NadamOptimizer(learning_rate=LEARNING_RATE)
#     optimizer = tf.train.AdamOptimizer()
    train_op = optimizer.minimize(loss_op, global_step=tf.train.get_global_step())
    
    # Evaluate the accuracy of the model
#     acc_op = tf.metrics.accuracy(labels=tf.argmax(labels, axis=1), predictions=pred_classes)
#     acc_op = tf.metrics.accuracy(labels=labels, predictions=pred_classes)
    ndcg_map = tf.map_fn(lambda x: ndcg(x[0], x[1]), (labels, pred_classes), dtype=tf.float32)
    ndcg_op = tf.metrics.mean(ndcg_map)
    top1_map = tf.map_fn(lambda x: top1Match(x[0], x[1]), (labels, pred_classes), dtype=tf.float32)
    top1_op = tf.metrics.mean(top1_map)
    top2_map = tf.map_fn(lambda x: top2Match(x[0], x[1]), (labels, pred_classes), dtype=tf.float32)
    top2_op = tf.metrics.mean(top2_map)
    spearman_map = tf.map_fn(lambda x: boundedSpearman(x[0], x[1]), (labels, pred_classes), dtype=tf.float32)
    acc_op = tf.metrics.mean(spearman_map)
    
    # TF Estimators requires to return a EstimatorSpec, that specify
    # the different ops for training, evaluating, ...
    estim_specs = tf.estimator.EstimatorSpec(
      mode=mode,
      predictions=pred_classes,
      loss=loss_op,
      train_op=train_op,
      eval_metric_ops={'accuracy': acc_op, 'ndcg': ndcg_op, 'top1Classification': top1_op, 'top2Classification': top2_op})

    return estim_specs

# %%
# Build the Estimator
config = tf.ConfigProto()
# config.gpu_options.per_process_gpu_memory_fraction = 0.8
model = tf.estimator.Estimator(modelFunc, config=tf.contrib.learn.RunConfig(session_config=config, save_summary_steps=10000, log_step_count_steps=10000))
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpw6yl6kuw
# INFO:tensorflow:Using config: {'_task_type': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f879b256860>, '_master': '', '_num_ps_replicas': 0, '_num_worker_replicas': 0, '_environment': 'local', '_is_chief': True, '_evaluation_master': '', '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_tf_random_seed': None, '_save_summary_steps': 10000, '_save_checkpoints_secs': 600, '_log_step_count_steps': 10000, '_session_config': , '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/tmp/tmpw6yl6kuw'}

# %%
trainResults = []
validResults = []

# %%
trainFunc = tf.estimator.inputs.numpy_input_fn(
    x={"input": inputsTrain.astype(np.float32)}, y=outputsTrain.astype(np.float32),
    batch_size=BATCH_SIZE, shuffle=False)

validFunc = tf.estimator.inputs.numpy_input_fn(
    x={"input": inputsValid.astype(np.float32)}, y=outputsValid.astype(np.float32),
    batch_size=BATCH_SIZE, shuffle=False)

# for i in range(0, 30):
model.train(inputFunc, steps=40000)

print("Evaluating Train")
accuracy = model.evaluate(trainFunc)
trainResults.append(accuracy)

print("Evaluating Valid")
accuracy = model.evaluate(validFunc)
validResults.append(accuracy)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpw6yl6kuw/model.ckpt.
# INFO:tensorflow:loss = 0.322451, step = 1
# INFO:tensorflow:loss = 0.313544, step = 101 (0.408 sec)
# INFO:tensorflow:loss = 0.312324, step = 201 (0.356 sec)
# INFO:tensorflow:loss = 0.312974, step = 301 (0.325 sec)
# INFO:tensorflow:loss = 0.310869, step = 401 (0.311 sec)
# INFO:tensorflow:loss = 0.313829, step = 501 (0.344 sec)
# INFO:tensorflow:loss = 0.31318, step = 601 (0.372 sec)
# INFO:tensorflow:loss = 0.313109, step = 701 (0.369 sec)
# INFO:tensorflow:loss = 0.310563, step = 801 (0.331 sec)
# INFO:tensorflow:loss = 0.306615, step = 901 (0.309 sec)
# INFO:tensorflow:loss = 0.303172, step = 1001 (0.303 sec)
# INFO:tensorflow:loss = 0.313593, step = 1101 (0.290 sec)
# INFO:tensorflow:loss = 0.306733, step = 1201 (0.349 sec)
# INFO:tensorflow:loss = 0.308235, step = 1301 (0.335 sec)
# INFO:tensorflow:loss = 0.307532, step = 1401 (0.325 sec)
# INFO:tensorflow:loss = 0.305438, step = 1501 (0.335 sec)
# INFO:tensorflow:loss = 0.310886, step = 1601 (0.298 sec)
# INFO:tensorflow:loss = 0.313499, step = 1701 (0.324 sec)
# INFO:tensorflow:loss = 0.309676, step = 1801 (0.325 sec)
# INFO:tensorflow:loss = 0.314971, step = 1901 (0.298 sec)
# INFO:tensorflow:loss = 0.310573, step = 2001 (0.319 sec)
# INFO:tensorflow:loss = 0.310918, step = 2101 (0.325 sec)
# INFO:tensorflow:loss = 0.307083, step = 2201 (0.309 sec)
# INFO:tensorflow:loss = 0.312341, step = 2301 (0.310 sec)
# INFO:tensorflow:loss = 0.309266, step = 2401 (0.372 sec)
# INFO:tensorflow:loss = 0.312709, step = 2501 (0.323 sec)
# INFO:tensorflow:loss = 0.308203, step = 2601 (0.318 sec)
# INFO:tensorflow:loss = 0.307878, step = 2701 (0.322 sec)
# INFO:tensorflow:loss = 0.310121, step = 2801 (0.317 sec)
# INFO:tensorflow:loss = 0.313624, step = 2901 (0.310 sec)
# INFO:tensorflow:loss = 0.308608, step = 3001 (0.320 sec)
# INFO:tensorflow:loss = 0.307169, step = 3101 (0.329 sec)
# INFO:tensorflow:loss = 0.312136, step = 3201 (0.316 sec)
# INFO:tensorflow:loss = 0.308946, step = 3301 (0.282 sec)
# INFO:tensorflow:loss = 0.311173, step = 3401 (0.319 sec)
# INFO:tensorflow:loss = 0.311327, step = 3501 (0.384 sec)
# INFO:tensorflow:loss = 0.309228, step = 3601 (0.354 sec)
# INFO:tensorflow:loss = 0.30917, step = 3701 (0.352 sec)
# INFO:tensorflow:loss = 0.30694, step = 3801 (0.364 sec)
# INFO:tensorflow:loss = 0.308732, step = 3901 (0.350 sec)
# INFO:tensorflow:loss = 0.309535, step = 4001 (0.343 sec)
# INFO:tensorflow:loss = 0.30591, step = 4101 (0.372 sec)
# INFO:tensorflow:loss = 0.307121, step = 4201 (0.386 sec)
# INFO:tensorflow:loss = 0.312507, step = 4301 (0.371 sec)
# INFO:tensorflow:loss = 0.311688, step = 4401 (0.343 sec)
# INFO:tensorflow:loss = 0.309848, step = 4501 (0.301 sec)
# INFO:tensorflow:loss = 0.311125, step = 4601 (0.315 sec)
# INFO:tensorflow:loss = 0.30733, step = 4701 (0.311 sec)
# INFO:tensorflow:loss = 0.307652, step = 4801 (0.307 sec)
# INFO:tensorflow:loss = 0.307655, step = 4901 (0.316 sec)
# INFO:tensorflow:loss = 0.309784, step = 5001 (0.323 sec)
# INFO:tensorflow:loss = 0.311473, step = 5101 (0.288 sec)
# INFO:tensorflow:loss = 0.313105, step = 5201 (0.310 sec)
# INFO:tensorflow:loss = 0.313944, step = 5301 (0.298 sec)
# INFO:tensorflow:loss = 0.306943, step = 5401 (0.319 sec)
# INFO:tensorflow:loss = 0.311659, step = 5501 (0.346 sec)
# INFO:tensorflow:loss = 0.31572, step = 5601 (0.332 sec)
# INFO:tensorflow:loss = 0.304974, step = 5701 (0.361 sec)
# INFO:tensorflow:loss = 0.313292, step = 5801 (0.379 sec)
# INFO:tensorflow:loss = 0.305327, step = 5901 (0.375 sec)
# INFO:tensorflow:loss = 0.308461, step = 6001 (0.391 sec)
# INFO:tensorflow:loss = 0.309249, step = 6101 (0.385 sec)
# INFO:tensorflow:loss = 0.309123, step = 6201 (0.349 sec)
# INFO:tensorflow:loss = 0.307688, step = 6301 (0.303 sec)
# INFO:tensorflow:loss = 0.308813, step = 6401 (0.372 sec)
# INFO:tensorflow:loss = 0.307565, step = 6501 (0.354 sec)
# INFO:tensorflow:loss = 0.307709, step = 6601 (0.351 sec)
# INFO:tensorflow:loss = 0.307482, step = 6701 (0.380 sec)
# INFO:tensorflow:loss = 0.31277, step = 6801 (0.367 sec)
# INFO:tensorflow:loss = 0.312411, step = 6901 (0.333 sec)
# INFO:tensorflow:loss = 0.30409, step = 7001 (0.377 sec)
# INFO:tensorflow:loss = 0.311485, step = 7101 (0.355 sec)
# INFO:tensorflow:loss = 0.31399, step = 7201 (0.370 sec)
# INFO:tensorflow:loss = 0.311975, step = 7301 (0.366 sec)
# INFO:tensorflow:loss = 0.309239, step = 7401 (0.347 sec)
# INFO:tensorflow:loss = 0.312194, step = 7501 (0.365 sec)
# INFO:tensorflow:loss = 0.307276, step = 7601 (0.375 sec)
# INFO:tensorflow:loss = 0.311258, step = 7701 (0.358 sec)
# INFO:tensorflow:loss = 0.315386, step = 7801 (0.331 sec)
# INFO:tensorflow:loss = 0.310329, step = 7901 (0.296 sec)
# INFO:tensorflow:loss = 0.309562, step = 8001 (0.323 sec)
# INFO:tensorflow:loss = 0.309071, step = 8101 (0.313 sec)
# INFO:tensorflow:loss = 0.309568, step = 8201 (0.314 sec)
# INFO:tensorflow:loss = 0.311614, step = 8301 (0.322 sec)
# INFO:tensorflow:loss = 0.311237, step = 8401 (0.338 sec)
# INFO:tensorflow:loss = 0.309363, step = 8501 (0.325 sec)
# INFO:tensorflow:loss = 0.310258, step = 8601 (0.365 sec)
# INFO:tensorflow:loss = 0.310015, step = 8701 (0.325 sec)
# INFO:tensorflow:loss = 0.310795, step = 8801 (0.315 sec)
# INFO:tensorflow:loss = 0.307818, step = 8901 (0.366 sec)
# INFO:tensorflow:loss = 0.312004, step = 9001 (0.361 sec)
# INFO:tensorflow:loss = 0.306062, step = 9101 (0.338 sec)
# INFO:tensorflow:loss = 0.306434, step = 9201 (0.311 sec)
# INFO:tensorflow:loss = 0.311304, step = 9301 (0.371 sec)
# INFO:tensorflow:loss = 0.309658, step = 9401 (0.346 sec)
# INFO:tensorflow:loss = 0.308852, step = 9501 (0.350 sec)
# INFO:tensorflow:loss = 0.312691, step = 9601 (0.373 sec)
# INFO:tensorflow:loss = 0.311672, step = 9701 (0.348 sec)
# INFO:tensorflow:loss = 0.309654, step = 9801 (0.338 sec)
# INFO:tensorflow:loss = 0.307327, step = 9901 (0.370 sec)
# INFO:tensorflow:global_step/sec: 295.288
# INFO:tensorflow:loss = 0.308922, step = 10001 (0.331 sec)
# INFO:tensorflow:loss = 0.311021, step = 10101 (0.342 sec)
# INFO:tensorflow:loss = 0.31088, step = 10201 (0.322 sec)
# INFO:tensorflow:loss = 0.311399, step = 10301 (0.318 sec)
# INFO:tensorflow:loss = 0.308261, step = 10401 (0.318 sec)
# INFO:tensorflow:loss = 0.308624, step = 10501 (0.328 sec)
# INFO:tensorflow:loss = 0.311235, step = 10601 (0.305 sec)
# INFO:tensorflow:loss = 0.312692, step = 10701 (0.286 sec)
# INFO:tensorflow:loss = 0.31301, step = 10801 (0.317 sec)
# INFO:tensorflow:loss = 0.307644, step = 10901 (0.354 sec)
# INFO:tensorflow:loss = 0.314511, step = 11001 (0.353 sec)
# INFO:tensorflow:loss = 0.307358, step = 11101 (0.329 sec)
# INFO:tensorflow:loss = 0.305973, step = 11201 (0.338 sec)
# INFO:tensorflow:loss = 0.311357, step = 11301 (0.336 sec)
# INFO:tensorflow:loss = 0.308957, step = 11401 (0.316 sec)
# INFO:tensorflow:loss = 0.309412, step = 11501 (0.309 sec)
# INFO:tensorflow:loss = 0.310635, step = 11601 (0.332 sec)
# INFO:tensorflow:loss = 0.31345, step = 11701 (0.315 sec)
# INFO:tensorflow:loss = 0.311065, step = 11801 (0.358 sec)
# INFO:tensorflow:loss = 0.314141, step = 11901 (0.347 sec)
# INFO:tensorflow:loss = 0.312361, step = 12001 (0.336 sec)
# INFO:tensorflow:loss = 0.312331, step = 12101 (0.304 sec)
# INFO:tensorflow:loss = 0.309552, step = 12201 (0.293 sec)
# INFO:tensorflow:loss = 0.307834, step = 12301 (0.313 sec)
# INFO:tensorflow:loss = 0.307171, step = 12401 (0.329 sec)
# INFO:tensorflow:loss = 0.311076, step = 12501 (0.305 sec)
# INFO:tensorflow:loss = 0.310227, step = 12601 (0.324 sec)
# INFO:tensorflow:loss = 0.311587, step = 12701 (0.335 sec)
# INFO:tensorflow:loss = 0.309713, step = 12801 (0.314 sec)
# INFO:tensorflow:loss = 0.308378, step = 12901 (0.351 sec)
# INFO:tensorflow:loss = 0.310721, step = 13001 (0.316 sec)
# INFO:tensorflow:loss = 0.307489, step = 13101 (0.322 sec)
# INFO:tensorflow:loss = 0.311057, step = 13201 (0.311 sec)
# INFO:tensorflow:loss = 0.30866, step = 13301 (0.353 sec)
# INFO:tensorflow:loss = 0.315189, step = 13401 (0.358 sec)
# INFO:tensorflow:loss = 0.307269, step = 13501 (0.365 sec)
# INFO:tensorflow:loss = 0.308252, step = 13601 (0.343 sec)
# INFO:tensorflow:loss = 0.306969, step = 13701 (0.300 sec)
# INFO:tensorflow:loss = 0.313733, step = 13801 (0.312 sec)
# INFO:tensorflow:loss = 0.309427, step = 13901 (0.313 sec)
# INFO:tensorflow:loss = 0.310568, step = 14001 (0.356 sec)
# INFO:tensorflow:loss = 0.311544, step = 14101 (0.386 sec)
# INFO:tensorflow:loss = 0.309289, step = 14201 (0.316 sec)
# INFO:tensorflow:loss = 0.311305, step = 14301 (0.315 sec)
# INFO:tensorflow:loss = 0.3086, step = 14401 (0.337 sec)
# INFO:tensorflow:loss = 0.311243, step = 14501 (0.345 sec)
# INFO:tensorflow:loss = 0.310322, step = 14601 (0.300 sec)
# INFO:tensorflow:loss = 0.309059, step = 14701 (0.316 sec)
# INFO:tensorflow:loss = 0.312463, step = 14801 (0.342 sec)
# INFO:tensorflow:loss = 0.312357, step = 14901 (0.327 sec)
# INFO:tensorflow:loss = 0.31423, step = 15001 (0.316 sec)
# INFO:tensorflow:loss = 0.308423, step = 15101 (0.342 sec)
# INFO:tensorflow:loss = 0.304514, step = 15201 (0.311 sec)
# INFO:tensorflow:loss = 0.310272, step = 15301 (0.327 sec)
# INFO:tensorflow:loss = 0.308538, step = 15401 (0.338 sec)
# INFO:tensorflow:loss = 0.315187, step = 15501 (0.367 sec)
# INFO:tensorflow:loss = 0.312574, step = 15601 (0.327 sec)
# INFO:tensorflow:loss = 0.311155, step = 15701 (0.368 sec)
# INFO:tensorflow:loss = 0.312153, step = 15801 (0.386 sec)
# INFO:tensorflow:loss = 0.309898, step = 15901 (0.381 sec)
# INFO:tensorflow:loss = 0.312303, step = 16001 (0.317 sec)
# INFO:tensorflow:loss = 0.308238, step = 16101 (0.336 sec)
# INFO:tensorflow:loss = 0.307215, step = 16201 (0.319 sec)
# INFO:tensorflow:loss = 0.305569, step = 16301 (0.308 sec)
# INFO:tensorflow:loss = 0.310447, step = 16401 (0.324 sec)
# INFO:tensorflow:loss = 0.308482, step = 16501 (0.320 sec)
# INFO:tensorflow:loss = 0.30702, step = 16601 (0.338 sec)
# INFO:tensorflow:loss = 0.309524, step = 16701 (0.324 sec)
# INFO:tensorflow:loss = 0.312035, step = 16801 (0.323 sec)
# INFO:tensorflow:loss = 0.310325, step = 16901 (0.336 sec)
# INFO:tensorflow:loss = 0.308335, step = 17001 (0.335 sec)
# INFO:tensorflow:loss = 0.307218, step = 17101 (0.335 sec)
# INFO:tensorflow:loss = 0.309792, step = 17201 (0.350 sec)
# INFO:tensorflow:loss = 0.31302, step = 17301 (0.336 sec)
# INFO:tensorflow:loss = 0.307614, step = 17401 (0.311 sec)
# INFO:tensorflow:loss = 0.311264, step = 17501 (0.335 sec)
# INFO:tensorflow:loss = 0.315181, step = 17601 (0.326 sec)
# INFO:tensorflow:loss = 0.307291, step = 17701 (0.303 sec)
# INFO:tensorflow:loss = 0.310521, step = 17801 (0.320 sec)
# INFO:tensorflow:loss = 0.310175, step = 17901 (0.311 sec)
# INFO:tensorflow:loss = 0.311552, step = 18001 (0.325 sec)
# INFO:tensorflow:loss = 0.308529, step = 18101 (0.326 sec)
# INFO:tensorflow:loss = 0.309295, step = 18201 (0.315 sec)
# INFO:tensorflow:loss = 0.311239, step = 18301 (0.297 sec)
# INFO:tensorflow:loss = 0.303255, step = 18401 (0.314 sec)
# INFO:tensorflow:loss = 0.308441, step = 18501 (0.322 sec)
# INFO:tensorflow:loss = 0.308253, step = 18601 (0.323 sec)
# INFO:tensorflow:loss = 0.311422, step = 18701 (0.323 sec)
# INFO:tensorflow:loss = 0.307103, step = 18801 (0.283 sec)
# INFO:tensorflow:loss = 0.31368, step = 18901 (0.319 sec)
# INFO:tensorflow:loss = 0.308602, step = 19001 (0.356 sec)
# INFO:tensorflow:loss = 0.313952, step = 19101 (0.366 sec)
# INFO:tensorflow:loss = 0.310721, step = 19201 (0.315 sec)
# INFO:tensorflow:loss = 0.310849, step = 19301 (0.307 sec)
# INFO:tensorflow:loss = 0.309674, step = 19401 (0.311 sec)
# INFO:tensorflow:loss = 0.310603, step = 19501 (0.321 sec)
# INFO:tensorflow:loss = 0.309239, step = 19601 (0.325 sec)
# INFO:tensorflow:loss = 0.309668, step = 19701 (0.322 sec)
# INFO:tensorflow:loss = 0.309305, step = 19801 (0.294 sec)
# INFO:tensorflow:loss = 0.308884, step = 19901 (0.291 sec)
# INFO:tensorflow:global_step/sec: 306.014
# INFO:tensorflow:loss = 0.3107, step = 20001 (0.295 sec)
# INFO:tensorflow:loss = 0.305859, step = 20101 (0.304 sec)
# INFO:tensorflow:loss = 0.307989, step = 20201 (0.342 sec)
# INFO:tensorflow:loss = 0.309957, step = 20301 (0.353 sec)
# INFO:tensorflow:loss = 0.313298, step = 20401 (0.310 sec)
# INFO:tensorflow:loss = 0.309388, step = 20501 (0.307 sec)
# INFO:tensorflow:loss = 0.308867, step = 20601 (0.303 sec)
# INFO:tensorflow:loss = 0.311672, step = 20701 (0.314 sec)
# INFO:tensorflow:loss = 0.31233, step = 20801 (0.295 sec)
# INFO:tensorflow:loss = 0.311038, step = 20901 (0.308 sec)
# INFO:tensorflow:loss = 0.304396, step = 21001 (0.310 sec)
# INFO:tensorflow:loss = 0.310275, step = 21101 (0.298 sec)
# INFO:tensorflow:loss = 0.306991, step = 21201 (0.294 sec)
# INFO:tensorflow:loss = 0.314528, step = 21301 (0.340 sec)
# INFO:tensorflow:loss = 0.312198, step = 21401 (0.343 sec)
# INFO:tensorflow:loss = 0.311839, step = 21501 (0.331 sec)
# INFO:tensorflow:loss = 0.311014, step = 21601 (0.324 sec)
# INFO:tensorflow:loss = 0.311427, step = 21701 (0.319 sec)
# INFO:tensorflow:loss = 0.311398, step = 21801 (0.307 sec)
# INFO:tensorflow:loss = 0.30948, step = 21901 (0.305 sec)
# INFO:tensorflow:loss = 0.309916, step = 22001 (0.325 sec)
# INFO:tensorflow:loss = 0.312178, step = 22101 (0.324 sec)
# INFO:tensorflow:loss = 0.30786, step = 22201 (0.337 sec)
# INFO:tensorflow:loss = 0.306889, step = 22301 (0.331 sec)
# INFO:tensorflow:loss = 0.311685, step = 22401 (0.316 sec)
# INFO:tensorflow:loss = 0.312053, step = 22501 (0.309 sec)
# INFO:tensorflow:loss = 0.312832, step = 22601 (0.317 sec)
# INFO:tensorflow:loss = 0.310916, step = 22701 (0.320 sec)
# INFO:tensorflow:loss = 0.310064, step = 22801 (0.326 sec)
# INFO:tensorflow:loss = 0.310028, step = 22901 (0.334 sec)
# INFO:tensorflow:loss = 0.309844, step = 23001 (0.321 sec)
# INFO:tensorflow:loss = 0.314068, step = 23101 (0.347 sec)
# INFO:tensorflow:loss = 0.310502, step = 23201 (0.319 sec)
# INFO:tensorflow:loss = 0.310365, step = 23301 (0.317 sec)
# INFO:tensorflow:loss = 0.307051, step = 23401 (0.301 sec)
# INFO:tensorflow:loss = 0.307693, step = 23501 (0.306 sec)
# INFO:tensorflow:loss = 0.306529, step = 23601 (0.312 sec)
# INFO:tensorflow:loss = 0.311662, step = 23701 (0.329 sec)
# INFO:tensorflow:loss = 0.306559, step = 23801 (0.355 sec)
# INFO:tensorflow:loss = 0.306515, step = 23901 (0.337 sec)
# INFO:tensorflow:loss = 0.310421, step = 24001 (0.314 sec)
# INFO:tensorflow:loss = 0.310924, step = 24101 (0.314 sec)
# INFO:tensorflow:loss = 0.308523, step = 24201 (0.303 sec)
# INFO:tensorflow:loss = 0.31179, step = 24301 (0.336 sec)
# INFO:tensorflow:loss = 0.314318, step = 24401 (0.324 sec)
# INFO:tensorflow:loss = 0.311736, step = 24501 (0.334 sec)
# INFO:tensorflow:loss = 0.308157, step = 24601 (0.311 sec)
# INFO:tensorflow:loss = 0.306593, step = 24701 (0.293 sec)
# INFO:tensorflow:loss = 0.308494, step = 24801 (0.317 sec)
# INFO:tensorflow:loss = 0.314154, step = 24901 (0.307 sec)
# INFO:tensorflow:loss = 0.310816, step = 25001 (0.311 sec)
# INFO:tensorflow:loss = 0.3143, step = 25101 (0.310 sec)
# INFO:tensorflow:loss = 0.308317, step = 25201 (0.319 sec)
# INFO:tensorflow:loss = 0.308733, step = 25301 (0.306 sec)
# INFO:tensorflow:loss = 0.313282, step = 25401 (0.339 sec)
# INFO:tensorflow:loss = 0.318325, step = 25501 (0.317 sec)
# INFO:tensorflow:loss = 0.307681, step = 25601 (0.312 sec)
# INFO:tensorflow:loss = 0.313482, step = 25701 (0.300 sec)
# INFO:tensorflow:loss = 0.311501, step = 25801 (0.323 sec)
# INFO:tensorflow:loss = 0.30896, step = 25901 (0.315 sec)
# INFO:tensorflow:loss = 0.30679, step = 26001 (0.343 sec)
# INFO:tensorflow:loss = 0.313545, step = 26101 (0.321 sec)
# INFO:tensorflow:loss = 0.308229, step = 26201 (0.334 sec)
# INFO:tensorflow:loss = 0.315322, step = 26301 (0.325 sec)
# INFO:tensorflow:loss = 0.310744, step = 26401 (0.328 sec)
# INFO:tensorflow:loss = 0.30581, step = 26501 (0.328 sec)
# INFO:tensorflow:loss = 0.309939, step = 26601 (0.299 sec)
# INFO:tensorflow:loss = 0.30974, step = 26701 (0.327 sec)
# INFO:tensorflow:loss = 0.307755, step = 26801 (0.326 sec)
# INFO:tensorflow:loss = 0.311003, step = 26901 (0.334 sec)
# INFO:tensorflow:loss = 0.308981, step = 27001 (0.340 sec)
# INFO:tensorflow:loss = 0.308771, step = 27101 (0.289 sec)
# INFO:tensorflow:loss = 0.304848, step = 27201 (0.313 sec)
# INFO:tensorflow:loss = 0.309932, step = 27301 (0.327 sec)
# INFO:tensorflow:loss = 0.310035, step = 27401 (0.309 sec)
# INFO:tensorflow:loss = 0.31063, step = 27501 (0.347 sec)
# INFO:tensorflow:loss = 0.310205, step = 27601 (0.363 sec)
# INFO:tensorflow:loss = 0.311609, step = 27701 (0.325 sec)
# INFO:tensorflow:loss = 0.308695, step = 27801 (0.300 sec)
# INFO:tensorflow:loss = 0.307893, step = 27901 (0.308 sec)
# INFO:tensorflow:loss = 0.30836, step = 28001 (0.322 sec)
# INFO:tensorflow:loss = 0.307817, step = 28101 (0.307 sec)
# INFO:tensorflow:loss = 0.309915, step = 28201 (0.299 sec)
# INFO:tensorflow:loss = 0.311232, step = 28301 (0.314 sec)
# INFO:tensorflow:loss = 0.309469, step = 28401 (0.307 sec)
# INFO:tensorflow:loss = 0.310897, step = 28501 (0.302 sec)
# INFO:tensorflow:loss = 0.31004, step = 28601 (0.291 sec)
# INFO:tensorflow:loss = 0.310071, step = 28701 (0.308 sec)
# INFO:tensorflow:loss = 0.308543, step = 28801 (0.304 sec)
# INFO:tensorflow:loss = 0.310645, step = 28901 (0.305 sec)
# INFO:tensorflow:loss = 0.313239, step = 29001 (0.311 sec)
# INFO:tensorflow:loss = 0.312887, step = 29101 (0.334 sec)
# INFO:tensorflow:loss = 0.306438, step = 29201 (0.317 sec)
# INFO:tensorflow:loss = 0.307577, step = 29301 (0.283 sec)
# INFO:tensorflow:loss = 0.308632, step = 29401 (0.296 sec)
# INFO:tensorflow:loss = 0.311016, step = 29501 (0.307 sec)
# INFO:tensorflow:loss = 0.310268, step = 29601 (0.346 sec)
# INFO:tensorflow:loss = 0.312311, step = 29701 (0.303 sec)
# INFO:tensorflow:loss = 0.30969, step = 29801 (0.312 sec)
# INFO:tensorflow:loss = 0.310442, step = 29901 (0.306 sec)
# INFO:tensorflow:global_step/sec: 314.399
# INFO:tensorflow:loss = 0.312056, step = 30001 (0.356 sec)
# INFO:tensorflow:loss = 0.308517, step = 30101 (0.318 sec)
# INFO:tensorflow:loss = 0.311921, step = 30201 (0.322 sec)
# INFO:tensorflow:loss = 0.312865, step = 30301 (0.340 sec)
# INFO:tensorflow:loss = 0.313924, step = 30401 (0.322 sec)
# INFO:tensorflow:loss = 0.311275, step = 30501 (0.294 sec)
# INFO:tensorflow:loss = 0.310723, step = 30601 (0.360 sec)
# INFO:tensorflow:loss = 0.308, step = 30701 (0.310 sec)
# INFO:tensorflow:loss = 0.306409, step = 30801 (0.309 sec)
# INFO:tensorflow:loss = 0.306632, step = 30901 (0.331 sec)
# INFO:tensorflow:loss = 0.308464, step = 31001 (0.334 sec)
# INFO:tensorflow:loss = 0.309649, step = 31101 (0.295 sec)
# INFO:tensorflow:loss = 0.308574, step = 31201 (0.361 sec)
# INFO:tensorflow:loss = 0.30779, step = 31301 (0.316 sec)
# INFO:tensorflow:loss = 0.311354, step = 31401 (0.294 sec)
# INFO:tensorflow:loss = 0.309207, step = 31501 (0.298 sec)
# INFO:tensorflow:loss = 0.311261, step = 31601 (0.299 sec)
# INFO:tensorflow:loss = 0.31346, step = 31701 (0.307 sec)
# INFO:tensorflow:loss = 0.310253, step = 31801 (0.329 sec)
# INFO:tensorflow:loss = 0.311857, step = 31901 (0.332 sec)
# INFO:tensorflow:loss = 0.30382, step = 32001 (0.326 sec)
# INFO:tensorflow:loss = 0.310142, step = 32101 (0.323 sec)
# INFO:tensorflow:loss = 0.30979, step = 32201 (0.314 sec)
# INFO:tensorflow:loss = 0.30892, step = 32301 (0.334 sec)
# INFO:tensorflow:loss = 0.313237, step = 32401 (0.333 sec)
# INFO:tensorflow:loss = 0.312749, step = 32501 (0.308 sec)
# INFO:tensorflow:loss = 0.313805, step = 32601 (0.287 sec)
# INFO:tensorflow:loss = 0.310847, step = 32701 (0.308 sec)
# INFO:tensorflow:loss = 0.308579, step = 32801 (0.320 sec)
# INFO:tensorflow:loss = 0.306182, step = 32901 (0.309 sec)
# INFO:tensorflow:loss = 0.309118, step = 33001 (0.300 sec)
# INFO:tensorflow:loss = 0.311556, step = 33101 (0.362 sec)
# INFO:tensorflow:loss = 0.311407, step = 33201 (0.313 sec)
# INFO:tensorflow:loss = 0.312535, step = 33301 (0.334 sec)
# INFO:tensorflow:loss = 0.3115, step = 33401 (0.341 sec)
# INFO:tensorflow:loss = 0.309587, step = 33501 (0.341 sec)
# INFO:tensorflow:loss = 0.311417, step = 33601 (0.333 sec)
# INFO:tensorflow:loss = 0.305483, step = 33701 (0.305 sec)
# INFO:tensorflow:loss = 0.309308, step = 33801 (0.318 sec)
# INFO:tensorflow:loss = 0.309447, step = 33901 (0.303 sec)
# INFO:tensorflow:loss = 0.310822, step = 34001 (0.304 sec)
# INFO:tensorflow:loss = 0.309751, step = 34101 (0.315 sec)
# INFO:tensorflow:loss = 0.304975, step = 34201 (0.334 sec)
# INFO:tensorflow:loss = 0.309144, step = 34301 (0.354 sec)
# INFO:tensorflow:loss = 0.309895, step = 34401 (0.287 sec)
# INFO:tensorflow:loss = 0.312918, step = 34501 (0.307 sec)
# INFO:tensorflow:loss = 0.310433, step = 34601 (0.308 sec)
# INFO:tensorflow:loss = 0.310365, step = 34701 (0.321 sec)
# INFO:tensorflow:loss = 0.310628, step = 34801 (0.353 sec)
# INFO:tensorflow:loss = 0.312418, step = 34901 (0.313 sec)
# INFO:tensorflow:loss = 0.310047, step = 35001 (0.279 sec)
# INFO:tensorflow:loss = 0.305381, step = 35101 (0.318 sec)
# INFO:tensorflow:loss = 0.312228, step = 35201 (0.319 sec)
# INFO:tensorflow:loss = 0.303631, step = 35301 (0.303 sec)
# INFO:tensorflow:loss = 0.306483, step = 35401 (0.314 sec)
# INFO:tensorflow:loss = 0.307313, step = 35501 (0.310 sec)
# INFO:tensorflow:loss = 0.312746, step = 35601 (0.316 sec)
# INFO:tensorflow:loss = 0.310759, step = 35701 (0.317 sec)
# INFO:tensorflow:loss = 0.307908, step = 35801 (0.324 sec)
# INFO:tensorflow:loss = 0.312947, step = 35901 (0.333 sec)
# INFO:tensorflow:loss = 0.311233, step = 36001 (0.331 sec)
# INFO:tensorflow:loss = 0.307292, step = 36101 (0.326 sec)
# INFO:tensorflow:loss = 0.3144, step = 36201 (0.355 sec)
# INFO:tensorflow:loss = 0.310121, step = 36301 (0.365 sec)
# INFO:tensorflow:loss = 0.312034, step = 36401 (0.357 sec)
# INFO:tensorflow:loss = 0.313787, step = 36501 (0.332 sec)
# INFO:tensorflow:loss = 0.313706, step = 36601 (0.321 sec)
# INFO:tensorflow:loss = 0.312036, step = 36701 (0.322 sec)
# INFO:tensorflow:loss = 0.310565, step = 36801 (0.303 sec)
# INFO:tensorflow:loss = 0.307806, step = 36901 (0.296 sec)
# INFO:tensorflow:loss = 0.30786, step = 37001 (0.291 sec)
# INFO:tensorflow:loss = 0.308589, step = 37101 (0.299 sec)
# INFO:tensorflow:loss = 0.30797, step = 37201 (0.297 sec)
# INFO:tensorflow:loss = 0.309232, step = 37301 (0.290 sec)
# INFO:tensorflow:loss = 0.311123, step = 37401 (0.316 sec)
# INFO:tensorflow:loss = 0.307638, step = 37501 (0.345 sec)
# INFO:tensorflow:loss = 0.310506, step = 37601 (0.298 sec)
# INFO:tensorflow:loss = 0.308012, step = 37701 (0.310 sec)
# INFO:tensorflow:loss = 0.308794, step = 37801 (0.313 sec)
# INFO:tensorflow:loss = 0.310214, step = 37901 (0.318 sec)
# INFO:tensorflow:loss = 0.314056, step = 38001 (0.315 sec)
# INFO:tensorflow:loss = 0.309706, step = 38101 (0.343 sec)
# INFO:tensorflow:loss = 0.308398, step = 38201 (0.315 sec)
# INFO:tensorflow:loss = 0.308909, step = 38301 (0.326 sec)
# INFO:tensorflow:loss = 0.305494, step = 38401 (0.298 sec)
# INFO:tensorflow:loss = 0.30814, step = 38501 (0.281 sec)
# INFO:tensorflow:loss = 0.311062, step = 38601 (0.283 sec)
# INFO:tensorflow:loss = 0.310068, step = 38701 (0.309 sec)
# INFO:tensorflow:loss = 0.308456, step = 38801 (0.332 sec)
# INFO:tensorflow:loss = 0.307913, step = 38901 (0.325 sec)
# INFO:tensorflow:loss = 0.312772, step = 39001 (0.295 sec)
# INFO:tensorflow:loss = 0.312914, step = 39101 (0.306 sec)
# INFO:tensorflow:loss = 0.313124, step = 39201 (0.314 sec)
# INFO:tensorflow:loss = 0.305407, step = 39301 (0.344 sec)
# INFO:tensorflow:loss = 0.31248, step = 39401 (0.288 sec)
# INFO:tensorflow:loss = 0.312772, step = 39501 (0.332 sec)
# INFO:tensorflow:loss = 0.310757, step = 39601 (0.373 sec)
# INFO:tensorflow:loss = 0.311048, step = 39701 (0.376 sec)
# INFO:tensorflow:loss = 0.309616, step = 39801 (0.374 sec)
# INFO:tensorflow:loss = 0.314851, step = 39901 (0.368 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into /tmp/tmpw6yl6kuw/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.311066.
# Evaluating Train
# INFO:tensorflow:Starting evaluation at 2018-05-06-19:23:10
# INFO:tensorflow:Restoring parameters from /tmp/tmpw6yl6kuw/model.ckpt-40000
# INFO:tensorflow:Finished evaluation at 2018-05-06-19:23:42
# INFO:tensorflow:Saving dict for global step 40000: accuracy = 0.504335, global_step = 40000, loss = 0.310118, ndcg = 0.871396, top1Classification = 0.761794, top2Classification = 0.988399
# Evaluating Valid
# INFO:tensorflow:Starting evaluation at 2018-05-06-19:23:43
# INFO:tensorflow:Restoring parameters from /tmp/tmpw6yl6kuw/model.ckpt-40000
# INFO:tensorflow:Finished evaluation at 2018-05-06-19:23:54
# INFO:tensorflow:Saving dict for global step 40000: accuracy = 0.493154, global_step = 40000, loss = 0.310956, ndcg = 0.87043, top1Classification = 0.726218, top2Classification = 0.990719

# %%
predictions = list(model.predict(validFunc))
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/tmpw6yl6kuw/model.ckpt-40000

# %%
import collections
collections.Counter(list(map(str, predictions)))
# Out:
# Counter({'[ 2.  1.  3.  4.  0.]': 2155})

# %%
collections.Counter(list(map(str, outputsValid)))
# Out:
# Counter({'[0 1 2 3 4]': 5,
#          '[0 1 2 4 3]': 5,
#          '[0 2 1 3 4]': 5,
#          '[0 2 1 4 3]': 145,
#          '[0 2 3 4 1]': 10,
#          '[0 2 4 1 3]': 275,
#          '[0 2 4 3 1]': 30,
#          '[2 0 1 3 4]': 5,
#          '[2 0 1 4 3]': 220,
#          '[2 0 3 1 4]': 10,
#          '[2 0 3 4 1]': 20,
#          '[2 0 4 1 3]': 295,
#          '[2 0 4 3 1]': 215,
#          '[2 1 3 4 0]': 10,
#          '[2 1 4 0 3]': 25,
#          '[2 3 1 4 0]': 10,
#          '[2 3 4 0 1]': 5,
#          '[2 3 4 1 0]': 5,
#          '[2 4 0 1 3]': 210,
#          '[2 4 0 3 1]': 175,
#          '[2 4 1 0 3]': 125,
#          '[2 4 1 3 0]': 110,
#          '[2 4 3 0 1]': 55,
#          '[2 4 3 1 0]': 70,
#          '[4 0 2 1 3]': 15,
#          '[4 1 2 0 3]': 5,
#          '[4 1 2 3 0]': 5,
#          '[4 2 0 1 3]': 35,
#          '[4 2 0 3 1]': 10,
#          '[4 2 1 0 3]': 10,
#          '[4 2 1 3 0]': 10,
#          '[4 2 3 1 0]': 20,
#          '[4 3 2 0 1]': 5})
